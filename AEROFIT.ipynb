# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####  Problem Statement

# %% [markdown]
# - As the people have started prioritising physical health,it is a great oppurtunity for the companies that manufacture equipments like treadmills to increase sales and get profit.Such a company known as Aerofit would like to know about the purchasing characteristics of people from the data available in their database.Analysis of this data can help in increasing the sales by giving purchase recommendations to future customers. Hence we are supposed find out the characteristics and purchase characteristics of future customers.

# %%
df=pd.read_csv("https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749")

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# - Details of 180 sales is given

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
#  - Customers are aged between 18 and 50 with an average age of 28
#  - All the customers have a minimum education of 12 years
#  - Customers with all kinds of fitness has bought the equipment
#  - Income varies between 29k to 104 k
#  - Customers use the machine atleast 2 days per week to maximum everyday
#  - Customers run between 21 miles to 360 miles per week
#  - Most bought item is KP261 among the three(80 out of 180)
#  - Majority of the customer is constitued by Males(107 out 0f 180)
#  - Majority of the customers are partnered(107 out of 180)

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# - Except product name,gender of customer and marital status all the data are in integer datatype
# - There are no missing values in any series

# %%
product_names=df["Product"].value_counts()
product_names
# Out:
# KP281    80
# KP481    60
# KP781    40
# Name: Product, dtype: int64

# %% [markdown]
# - Count of sales of different mdels are given above

# %%
sns.countplot(x=df["Product"])
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %% [markdown]
# - Most sold product is KP281

# %%
customer_gender=df["Gender"].value_counts()
customer_gender
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %% [markdown]
# - Males bought 104 treadmills whereas females bought 76

# %%
sns.countplot(x=df["MaritalStatus"])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# - Comapred to singles, partnered customers prefer to buy treadmills

# %%
Customer_education=df["Education"].value_counts()
Customer_education
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %% [markdown]
# - People with 16 years of education are maximum aamong the customers

# %%
sns.set_style('whitegrid')
sns.distplot(df['Education'], kde = False, color ='red', bins = 30)
# Out:
# <AxesSubplot:xlabel='Education'>

# %%
Customer_status=df["MaritalStatus"].value_counts()
Customer_status
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# - Majority of the customers are partnered

# %%
sns.countplot(x=df["MaritalStatus"])
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
Treadmill_usage=df["Usage"].value_counts()
Treadmill_usage
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %% [markdown]
# - Most of the customers use treadmills thrice a week folowed by 4 times a week

# %%
sns.set_style('whitegrid')
sns.displot(df['Usage'], kde = False, color ='green', bins = 30)

# %%
Customer_fitness=df["Fitness"].value_counts()
Customer_fitness
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %% [markdown]
# - Customers in fitness scale 3 constitutes more than half of customers

# %%
sns.set_style('whitegrid')
sns.displot(df['Fitness'], kde = False, color ='yellow', bins = 30)

# %% [markdown]
# - Value counts of  Age,Income,Miles does not make any sense as they are widely distributed

# %%
sns.set_style('whitegrid')
sns.distplot(df['Fitness'], kde = False, color ='blue', bins = 30)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fitness'>

# %%
sns.histplot(df["Age"],bins=4)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# - people between 18-26 are the most among the customers

# %%
sns.histplot(df["Income"],bins=4)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Count'>

# %% [markdown]
# - most customer fall in an income range of 49000 to 67000 followed by income range between 32000 to 49000(approximately)

# %%
sns.histplot(df["Miles"],bins=4)
# Out:
# <AxesSubplot:xlabel='Miles', ylabel='Count'>

# %% [markdown]
# - Majority of customers run for 20 to 100 miles a week

# %%
plt.boxplot(x=df["Miles"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15cdda8d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15cddb93d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15cdda8a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x15cddb98b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15cddb9b80>],
#  'means': []}

# %% [markdown]
# - Customers who run more than 175 miles per week are considered as outliers

# %%
plt.boxplot(x=df["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15d2adcb50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15d2adc760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15d2adc1c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15d2adcf70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15d25f00a0>],
#  'means': []}

# %% [markdown]
# - Customers aged above 46 are considered outliers

# %%
plt.boxplot(x=df["Income"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15d217a2b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15d17bf400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15d18591c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15d17bf2e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15d17bff10>],
#  'means': []}

# %% [markdown]
# - Customers aged above 76k are considered outliers

# %%
plt.boxplot(x=df["Fitness"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15eabba550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15eabbaaf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15eabba3a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15eabc80d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15eabc83a0>],
#  'means': []}

# %% [markdown]
# - Customers with fitness scale below 2 are considered outliers

# %%
plt.boxplot(x=df["Usage"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15e9909ca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15e991a280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15e9909af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15e991a820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15e991aaf0>],
#  'means': []}

# %% [markdown]
# - Customers with usage of treadmill more than 5 times a week and less than 2 times a week are considered outliers

# %%
sns.pairplot(df, hue ='Age')
plt.show()

# %%
sns.pairplot(df, hue ='Income')

# %%
sns.pairplot(df[["Age","Usage"]])

# %%
sns.pairplot(df[["Age","Miles"]])

# %%
sns.heatmap(data = df[["Age","Miles","Usage"]])
# Out:
# <AxesSubplot:>

# %%
sns.catplot(data=df, y="Product", x="MaritalStatus", hue="Gender", kind="swarm")
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 35.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data=df,
x="Product",
hue="Gender",)
plt.title('Gender Vs Product')
plt.xticks(rotation=60)
plt.legend(loc=(0.75,0.5))
plt.show()

# %% [markdown]
# - Basic model is preferred equally by Men and Women
# - As the Product features are more, women doesn't prefer it
# - More sophisticated product is more preferred by men compared to women
# - Men considers buying either a Basic one or an Advanced one more compared to the mid one

# %%
sns.countplot(data=df,
x="Product",
hue="MaritalStatus",)
plt.title('Gender Vs Product')
plt.xticks(rotation=60)
plt.legend(loc=(0.75,0.5))
plt.show()

# %% [markdown]
# - Partenered customers are more likely to buy a treadmill than single ones
# - They prefer the basic product more compared to the advanced one

# %%
df_female=df[df["Gender"]=="Female"]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 5     KP281   20  Female         14     Partnered      3        3   32973
# 6     KP281   21  Female         14     Partnered      3        3   35247
# 9     KP281   21  Female         15     Partnered      2        3   37521
# 11    KP281   22  Female         14     Partnered      3        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 152   KP781   25  Female         18     Partnered      5        5   61006
# 157   KP781   26  Female         21        Single      4        3   69721
# 162   KP781   28  Female         18     Partnered      6        5   92131
# 167   KP781   30  Female         16     Partnered      6        5   90886
# 171   KP781   33  Female         18     Partnered      4        5   95866
#
#      Miles
# 2       66
# 5       66
# 6       75
# 9       85
# 11      66
# ...

# %%
df_female.describe(include="all")
# Out:
#        Product        Age  Gender  Education MaritalStatus      Usage  \
# count       76  76.000000      76  76.000000            76  76.000000
# unique       3        NaN       1        NaN             2        NaN
# top      KP281        NaN  Female        NaN     Partnered        NaN
# freq        40        NaN      76        NaN            46        NaN
# mean       NaN  28.565789     NaN  15.394737           NaN   3.184211
# std        NaN   6.342104     NaN   1.442950           NaN   1.016012
# min        NaN  19.000000     NaN  13.000000           NaN   2.000000
# 25%        NaN  24.000000     NaN  14.000000           NaN   2.000000
# 50%        NaN  26.500000     NaN  16.000000           NaN   3.000000
# 75%        NaN  33.000000     NaN  16.000000           NaN   4.000000
# max        NaN  50.000000     NaN  21.000000           NaN   6.000000
#
#           Fitness        Income       Miles
# count   76.000000     76.000000   76.000000
# ...

# %%
df_male=df[df["Gender"]=="Male"]

# %%
df_male.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      104  104.000000    104  104.000000           104  104.000000
# unique       3         NaN      1         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        40         NaN    104         NaN            61         NaN
# mean       NaN   28.951923    NaN   15.701923           NaN    3.653846
# std        NaN    7.377978    NaN    1.728571           NaN    1.095172
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   23.750000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    4.000000
# 75%        NaN   34.000000    NaN   16.000000           NaN    4.000000
# max        NaN   48.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   104.000000     104.000000  104.000000
# ...

# %%
pd.crosstab(index=df["Product"],columns=df["Gender"],margins=True)
# Out:
# Gender   Female  Male  All
# Product
# KP281        40    40   80
# KP481        29    31   60
# KP781         7    33   40
# All          76   104  180

# %% [markdown]
# - Probability of a female customer buying KP281=50%
# - Probability of a male customer buying KP281=50%
# - Probability of a female customer buying KP481=48.33%
# - Probability of a male customer buying KP481=51.67%
# - Probability of a female customer buying KP781=17.5%
# - Probability of a male customer buying KP781=82.5%

# %% [markdown]
# - Percentage of customers purchased KP281 = 44.44%
# - Percentage of customers purchased KP481 = 33.33%
# - Percentage of customers purchased KP781 = 22.22%

# %% [markdown]
# - Percentage of Male customers = 57.78%
# - Percentage of Male customers = 42.22%

# %% [markdown]
# # Outliers

# %% [markdown]
# - Customers with usage of treadmill more than 5 times a week and less than 2 times a week are considered outliers
# - Customers with fitness scale below 2 are considered outliers
# - Customers aged above 76k are considered outliers
# - Customers aged above 46 are considered outliers
# - Customers who run more than 175 miles per week are considered as outliers

# %%
df_heatplot = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # Correlations

# %% [markdown]
# - Age is highly overall correlated with Income
# - Education is highly overall correlated with Income
# - Usage is highly overall correlated with Miles
# - Income is highly overall correlated with Age and Education
# - Miles is highly overall correlated with Usage and Fitness
# - Product is highly overall correlated with Fitness
# - Fitness is highly overall correlated with Miles and Usage

# %% [markdown]
# # Business Insights based on Non-Graphical and Visual Analysis

# %% [markdown]
# - Customers are aged between 18 and 50 with an average age of 28
# - All the customers have a minimum education of 12 years
# - Customers with all kinds of fitness has bought the equipment
# - Income varies between 29k to 104 k
# - Customers use the machine atleast 2 days per week to maximum everyday
# - Customers run between 21 miles to 360 miles per week
# - Most bought item is KP261 among the three(80 out of 180)
# - Majority of the customer is constitued by Males(107 out 0f 180)
# - Majority of the customers are partnered(107 out of 180)

# %% [markdown]
# # Conclusion of Customer Profiling

# %% [markdown]
# - Details of 180 sales is given
# - Males bought 104 treadmills whereas females bought 76
# - Comapred to singles(63), partnered(107) customers prefer to buy treadmills
# - People with 16 years of education are maximum aamong the customers
# - Most of the customers use treadmills thrice a week folowed by 4 times a week
# - Customers in fitness scale 3 constitutes more than half of customers
# - people between 18-26 are the most among the customers
# - most customer fall in an income range of 49000 to 67000 followed by income range between 32000 to 49000(approximately)
# - Majority of customers run for 20 to 100 miles a week

# %% [markdown]
# # Recommendations

# %% [markdown]
# - Probability of a female customer buying KP281=50%
# - Probability of a male customer buying KP281=50%
# - Probability of a female customer buying KP481=48.33%
# - Probability of a male customer buying KP481=51.67%
# - Probability of a female customer buying KP781=17.5%
# - Probability of a male customer buying KP781=82.5%
# - Percentage of customers purchased KP281 = 44.44%
# - Percentage of customers purchased KP481 = 33.33%
# - Percentage of customers purchased KP781 = 22.22%
# - Percentage of Male customers = 57.78%
# - Percentage of Male customers = 42.22%
